# %%
import os
from glob import glob
import re
import logging
from tqdm import tqdm
from itertools import chain

import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


import torch
from torch.utils.data import Dataset,DataLoader,random_split
import torchvision.transforms as transforms
from PIL import Image
import albumentations as A

from models import encoders, decoders
from src import datasets, utils, metrics


from torch import nn
from torch.nn import functional as F

# %%
from PIL import Image
import numpy as np
import cv2
import torch
from torch.utils.data import Dataset
import joblib

class Eurosat(Dataset):
    """
    This class takes in the folder with RGB Eurosat data and the file names after train/test split 
    Return the image tensor and the associated class of that image
    """
    def __init__(self, path, files, transform= None, augmentations=None):
        self.img_path = path   # Path to images
        self.files = files  # list of filenames in the file path
        self.transform = transforms.Compose([transform, 
        transforms.CenterCrop(size = 64),
        transforms.Resize(size = 224)])
        self.aug = augmentations

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):

        # Load the image 
        img_name = self.img_path + str(self.files[idx]) # this will be something like '/scratch/yc506/eurosat_rgb/Residential_2054.tif'
        # extract the image class with the name 
        name_class = str(self.files[idx]).lower().split('_')[0] # this will give us something like 'forest'
        class_map = {'annualcrop': 0 , 'forest':1, 'herbaceousvegetation': 2, 'highway':3, 'industrial':4, 'pasture': 5, 'permanentcrop':6,
                     'residential': 7, 'river': 8, 'sealake': 9
                      }
        img_class = class_map[name_class]

        # Apply albumentations augmentations
        # before applying the standard transform
        if self.aug:
            # Must convert to numpy array for
            # this to work nicely with albumentations
            # cv2 is the recommended method for reading images.
            # although you could just convert a PIL image to
            # a numpy array, too.
            img = cv2.imread(img_name)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Albumentations works more nicely if you
            augmented = self.aug(image=img)
            img = augmented["image"]

        else:

            img = Image.open(img_name).convert('RGB')
            
            # Apply resize 
            if self.transform:
                img = self.transform(img)


        return img.type(torch.FloatTensor), torch.tensor(img_class, dtype=torch.int64)

# %%
"""
This function loads the rgb data for Eurosat
"""
def load_eurosat(data_path , size=None, evaluate=False):
    size = None

    # a list of files in the data path 
    file_set = os.listdir(data_path)
 

    # train val test split 
    train_files, rem = train_test_split(file_set, test_size=0.2, random_state = 123)
    test_files, val_files = train_test_split(rem, test_size=0.5, random_state = 123)
    
    normalize = {"mean": [44.04389265, 49.10599284, 31.27095929], "std": [41.61620523, 38.21741166, 31.96225992]}

    tr_normalize = transforms.Normalize(mean=normalize["mean"], std=normalize["std"])
    train_transform = transforms.Compose([transforms.ToTensor(), tr_normalize])
    test_transform = transforms.Compose([transforms.ToTensor(), tr_normalize])
    train_dataset = Eurosat(data_path, train_files, transform=train_transform)
    val_dataset = Eurosat(data_path, val_files, transform=test_transform)
    # Return the training and test dataset
    test_dataset = Eurosat(data_path, test_files, transform=test_transform)
    if evaluate:
        return test_dataset

    return train_dataset, val_dataset

# %%
# loading the data 
train_data, test_data = load_eurosat("/scratch/yc506/NewEuroSat_rgb/" )

train_loader = DataLoader(
    train_data, batch_size=20, shuffle=True)
test_loader = DataLoader(
    test_data, batch_size=20, shuffle=False)

# %%
import torch
from torchvision.models import resnet50 as r50
from models.base import resnet

## from the encoder file 

def _append_state_dict_to_resnet(state_dict):

    # Remove keys that we don't need
    state_dict.pop("fc.bias")
    state_dict.pop("fc.weight")
    base_model = resnet.resnet50(inter_features=True)
    base_model.load_state_dict(state_dict)
    return base_model

def load_imagenet_encoder():
    """
    This model loads the weights from the SwAV model and places them
    onto this version of the ResNet model which allows the layers
    to be passed forward 
    """
    model = r50(pretrained=True)
    return _append_state_dict_to_resnet(model.state_dict())

# %%
def load_swav_pretrained(model_path):
    """
    This function loads the swav encoder pretrained on the solar training
    dataset.
    """
    state_dict = torch.load(model_path)
    base_model = resnet.resnet50(inter_features=True)
    base_model.load_state_dict(state_dict)

    return base_model

# %%
####### Linear evaluation class ############
####### reference : SwAV github 
class RegLog(nn.Module):
    """Creates logistic regression on top of frozen features"""

    def __init__(self, num_labels, global_avg=False, use_bn=True):
        super(RegLog, self).__init__()
        self.bn = None
        if global_avg:
            s = 2048
            self.av_pool = nn.AdaptiveAvgPool2d((1, 1))
        else:
            s = 8192
            self.av_pool = nn.AvgPool2d(6, stride=1)
            if use_bn:
                self.bn = nn.BatchNorm2d(2048)
        self.linear = nn.Linear(s, num_labels)
        self.linear.weight.data.normal_(mean=0.0, std=0.01)
        self.linear.bias.data.zero_()

    def forward(self, x):
        # average pool the final feature map
        x = self.av_pool(x)

        # optional BN
        if self.bn is not None:
            x = self.bn(x)

        # flatten
        x = x.view(x.size(0), -1)

        # linear layer
        return self.linear(x)

# %%
encoder = load_swav_pretrained("/scratch/mh613/model_paths/ckp-200-eval.pth")
decoder = RegLog(10)
#decoder = LinearClassifier(2048, 10)

# %%
global DEVICE

def set_device(d):
    if d == "auto":
        device = "cuda" if torch.cuda.is_available() else "cpu"
    else:
        device = d
    return device

DEVICE = set_device("auto")
#DEVICE = set_device('cpu')
print("Device is " + DEVICE)
encoder = encoder.to(DEVICE)
decoder = decoder.to(DEVICE)

params = decoder.parameters()
# Out:
# Device is cuda

# %%
def save_model(enc, dec, dump_path, name):
    torch.save(enc.state_dict(), os.path.join(dump_path, "enc_" + name))
    torch.save(dec.state_dict(), os.path.join(dump_path, "dec_" + name))

def train(loader, encoder, decoder, optimizer, criterion, fine_tune_encoder = False):

    if fine_tune_encoder:
        encoder.train()
    else:
        encoder.eval()

    decoder.train()
    criterion = criterion.to(DEVICE)
    avg_loss = utils.AverageMeter()
    num_batches = len(loader)
    for batch_idx, (inp, target) in enumerate(loader):
        if batch_idx % 10 == 0:
            print(f"Beginning batch {batch_idx} of {num_batches}")
        logging.debug(f"Training batch {batch_idx}...")
        # Move to the GPU
        inp = inp.to(DEVICE)
        target = target.to(DEVICE)

        if fine_tune_encoder:
            output = encoder(inp)
        else:
            with torch.no_grad():
                output = encoder(inp)
        ################### The change I'm not super sure #####################
        output = decoder(output[0])
        ########################################################################
        loss = criterion(output, target)

        if batch_idx % 10 == 0:
            print(f"\t Train Loss: {loss.item()}")
        # Calculate the gradients
        optimizer.zero_grad()
        loss.backward()
        avg_loss.update(loss.item(), inp.size(0))
        # Step forward
        optimizer.step()

    return avg_loss.avg

# %%
@torch.no_grad()
def test(data_loader, encoder, decoder, criterion):

    encoder.eval()
    decoder.eval()
    criterion = criterion.to(DEVICE)
    avg_loss = utils.AverageMeter()
    for batch_idx, (inp, target) in enumerate(data_loader):
        # Move to the GPU
        if batch_idx % 100 == 0:
            print(f"Testing batch {batch_idx}")
        inp = inp.to(DEVICE)
        target = target.to(DEVICE)

        # Compute output
        
        ################### The change I'm not super sure #####################
        output = encoder(inp)
        output = decoder(output[0])
        ########################################################################
        loss = criterion(output, target)
        avg_loss.update(loss.item(), inp.size(0))
        if batch_idx % 10 == 0:
            print(f"\t Test Loss: {loss.item()}")

    return avg_loss.avg

# %%
# probably needs to change
optimizer = torch.optim.Adam(
    decoder.parameters(), lr=1e-3, weight_decay=0)

# %%
criterion =  nn.CrossEntropyLoss().to(DEVICE)
monitor_pth = "/home/yc506/ssrs/experiments/results/eurosat_resize_swav"

epoch_timer = utils.Timer()
monitor = utils.PerformanceMonitor(monitor_pth)
best_test_loss = float("inf")
# do 100 epochs
for epoch in range(100):
    print(f"Beginning epoch {epoch}")
    logging.info(f"Beginning epoch {epoch}...")

    loss = train(train_loader, encoder, decoder, optimizer, criterion)
    monitor.log(epoch, "train", loss)

    loss = test(test_loader, encoder, decoder, criterion)
    monitor.log(epoch, "val", loss)
    logging.info(
        f"Epoch {epoch} took {epoch_timer.minutes_elapsed()} minutes.")
    epoch_timer.reset()

    if loss < best_test_loss:
        logging.info("Saving model")
        save_model(encoder, decoder, monitor_pth, "best.pt")
        best_test_loss = loss
save_model(encoder, decoder, monitor_pth, "final.pt")
# Out:
# Beginning epoch 0
# Beginning batch 0 of 587
# 	 Train Loss: 2.362987995147705
# Beginning batch 10 of 587
# 	 Train Loss: 2.4615566730499268
# Beginning batch 20 of 587
# 	 Train Loss: 2.3499529361724854
# Beginning batch 30 of 587
# 	 Train Loss: 2.2910475730895996
# Beginning batch 40 of 587
# 	 Train Loss: 1.9776426553726196
# Beginning batch 50 of 587
# 	 Train Loss: 2.5956015586853027
# Beginning batch 60 of 587
# 	 Train Loss: 2.32281231880188
# Beginning batch 70 of 587
# 	 Train Loss: 1.817058801651001
# Beginning batch 80 of 587
# 	 Train Loss: 2.445713520050049
# Beginning batch 90 of 587
# 	 Train Loss: 2.0471105575561523
# Beginning batch 100 of 587
# 	 Train Loss: 2.1202099323272705
# Beginning batch 110 of 587
# 	 Train Loss: 2.16226863861084
# Beginning batch 120 of 587
# 	 Train Loss: 1.934025764465332
# Beginning batch 130 of 587
# 	 Train Loss: 1.6311256885528564
# Beginning batch 140 of 587
# 	 Train Loss: 2.3094778060913086
# Beginning batch 150 of 587
# 	 Train Loss: 1.6550853252410889
# Beginning batch 160 of 587
# 	 Train Loss: 1.9889228343963623
# Beginning batch 170 of 587
# 	 Train Loss: 1.5913035869598389
# Beginning batch 180 of 587
# 	 Train Loss: 1.9125616550445557
# Beginning batch 190 of 587
# 	 Train Loss: 1.9783029556274414
# Beginning batch 200 of 587
# 	 Train Loss: 1.955648422241211
# Beginning batch 210 of 587
# 	 Train Loss: 1.9403270483016968
# Beginning batch 220 of 587
# 	 Train Loss: 1.6713947057724
# Beginning batch 230 of 587
# 	 Train Loss: 1.388428807258606
# Beginning batch 240 of 587
# 	 Train Loss: 1.7125641107559204
# Beginning batch 250 of 587
# 	 Train Loss: 1.8771564960479736
# Beginning batch 260 of 587
# 	 Train Loss: 2.331611394882202
# Beginning batch 270 of 587
# 	 Train Loss: 2.508492946624756
# Beginning batch 280 of 587
# 	 Train Loss: 1.9219993352890015
# Beginning batch 290 of 587
# 	 Train Loss: 1.716856598854065
# Beginning batch 300 of 587
# 	 Train Loss: 2.09800386428833
# Beginning batch 310 of 587
# 	 Train Loss: 2.0249805450439453
# Beginning batch 320 of 587
# 	 Train Loss: 1.7995426654815674
# Beginning batch 330 of 587
# 	 Train Loss: 2.0717828273773193
# Beginning batch 340 of 587
# 	 Train Loss: 1.7154992818832397
# Beginning batch 350 of 587
# 	 Train Loss: 1.4085288047790527
# Beginning batch 360 of 587
# 	 Train Loss: 1.7856862545013428
# Beginning batch 370 of 587
# 	 Train Loss: 1.5467458963394165
# Beginning batch 380 of 587
# 	 Train Loss: 1.6504671573638916
# Beginning batch 390 of 587
# 	 Train Loss: 1.9613434076309204
# Beginning batch 400 of 587
# 	 Train Loss: 1.5686761140823364
# Beginning batch 410 of 587
# 	 Train Loss: 1.5094904899597168
# Beginning batch 420 of 587
# 	 Train Loss: 1.6958777904510498
# Beginning batch 430 of 587
# 	 Train Loss: 1.7894128561019897
# Beginning batch 440 of 587
# 	 Train Loss: 1.5634479522705078
# Beginning batch 450 of 587
# 	 Train Loss: 2.264688730239868
# Beginning batch 460 of 587
# 	 Train Loss: 1.390762448310852
# Beginning batch 470 of 587
# 	 Train Loss: 2.1953558921813965
# Beginning batch 480 of 587
# 	 Train Loss: 2.019829034805298
# Beginning batch 490 of 587
# 	 Train Loss: 2.0067882537841797
# Beginning batch 500 of 587
# 	 Train Loss: 1.8477575778961182
# Beginning batch 510 of 587
# 	 Train Loss: 1.4560785293579102
# Beginning batch 520 of 587
# 	 Train Loss: 1.9739965200424194
# Beginning batch 530 of 587
# 	 Train Loss: 1.7395811080932617
# Beginning batch 540 of 587
# 	 Train Loss: 1.8996126651763916
# Beginning batch 550 of 587
# 	 Train Loss: 1.5242350101470947
# Beginning batch 560 of 587
# 	 Train Loss: 2.0522029399871826
# Beginning batch 570 of 587
# 	 Train Loss: 1.9853922128677368
# Beginning batch 580 of 587
# 	 Train Loss: 2.1997525691986084
# Testing batch 0
# 	 Test Loss: 2.1312670707702637
# 	 Test Loss: 1.8985430002212524
# 	 Test Loss: 1.8453916311264038
# 	 Test Loss: 1.431331992149353
# 	 Test Loss: 1.8717797994613647
# 	 Test Loss: 1.9581884145736694
# 	 Test Loss: 1.7458679676055908
# 	 Test Loss: 1.6747972965240479
# Beginning epoch 1
# Beginning batch 0 of 587
# 	 Train Loss: 1.6664241552352905
# Beginning batch 10 of 587
# 	 Train Loss: 1.6444114446640015
# Beginning batch 20 of 587
# 	 Train Loss: 1.4861233234405518
# Beginning batch 30 of 587
# 	 Train Loss: 1.9276478290557861
# Beginning batch 40 of 587
# 	 Train Loss: 2.0077624320983887
# Beginning batch 50 of 587
# 	 Train Loss: 1.8076601028442383
# Beginning batch 60 of 587
# 	 Train Loss: 1.4871032238006592
# Beginning batch 70 of 587
# 	 Train Loss: 1.6092637777328491
# Beginning batch 80 of 587
# 	 Train Loss: 1.7473809719085693
# Beginning batch 90 of 587
# 	 Train Loss: 1.89188551902771
# Beginning batch 100 of 587
# 	 Train Loss: 1.7596533298492432
# Beginning batch 110 of 587
# 	 Train Loss: 1.4717127084732056
# Beginning batch 120 of 587
# 	 Train Loss: 1.7002384662628174
# Beginning batch 130 of 587
# 	 Train Loss: 2.104003429412842
# Beginning batch 140 of 587
# 	 Train Loss: 1.9304771423339844
# Beginning batch 150 of 587
# 	 Train Loss: 1.5686724185943604
# Beginning batch 160 of 587
# 	 Train Loss: 1.251556158065796
# Beginning batch 170 of 587
# 	 Train Loss: 1.8396127223968506
# Beginning batch 180 of 587
# 	 Train Loss: 1.6240196228027344
# Beginning batch 190 of 587
# 	 Train Loss: 1.6491553783416748
# Beginning batch 200 of 587
# 	 Train Loss: 1.7248672246932983
# Beginning batch 210 of 587
# 	 Train Loss: 1.5993854999542236
# Beginning batch 220 of 587
# 	 Train Loss: 1.5235815048217773
# Beginning batch 230 of 587
# 	 Train Loss: 1.8390676975250244
# Beginning batch 240 of 587
# 	 Train Loss: 1.9054193496704102
# Beginning batch 250 of 587
# 	 Train Loss: 1.4342455863952637
# Beginning batch 260 of 587
# 	 Train Loss: 1.7485942840576172
# Beginning batch 270 of 587
# 	 Train Loss: 1.4635636806488037
# Beginning batch 280 of 587
# 	 Train Loss: 2.3669238090515137
# Beginning batch 290 of 587
# 	 Train Loss: 1.6711103916168213
# Beginning batch 300 of 587
# 	 Train Loss: 1.7417442798614502
# Beginning batch 310 of 587
# 	 Train Loss: 1.4493334293365479
# Beginning batch 320 of 587
# 	 Train Loss: 1.4535549879074097
# Beginning batch 330 of 587
# 	 Train Loss: 1.6723486185073853
# Beginning batch 340 of 587
# 	 Train Loss: 1.4137977361679077
# Beginning batch 350 of 587
# 	 Train Loss: 1.4201304912567139
# Beginning batch 360 of 587
# 	 Train Loss: 1.305934190750122
# Beginning batch 370 of 587
# 	 Train Loss: 1.5757014751434326
# Beginning batch 380 of 587
# 	 Train Loss: 1.8737882375717163
# Beginning batch 390 of 587
# 	 Train Loss: 1.935685157775879
# Beginning batch 400 of 587
# 	 Train Loss: 1.7905784845352173
# Beginning batch 410 of 587
# 	 Train Loss: 1.552868366241455
# Beginning batch 420 of 587
# 	 Train Loss: 1.8726131916046143
# Beginning batch 430 of 587
# 	 Train Loss: 1.4309608936309814
# Beginning batch 440 of 587
# 	 Train Loss: 1.5036227703094482
# Beginning batch 450 of 587
# 	 Train Loss: 1.4811732769012451
# Beginning batch 460 of 587
# 	 Train Loss: 1.4868404865264893
# Beginning batch 470 of 587
# 	 Train Loss: 1.4562032222747803
# Beginning batch 480 of 587
# 	 Train Loss: 1.5135196447372437
# Beginning batch 490 of 587
# 	 Train Loss: 1.2874900102615356
# Beginning batch 500 of 587
# 	 Train Loss: 1.5676087141036987
# Beginning batch 510 of 587
# 	 Train Loss: 1.8459079265594482
# Beginning batch 520 of 587
# 	 Train Loss: 1.7495962381362915
# Beginning batch 530 of 587
# 	 Train Loss: 2.094576120376587
# Beginning batch 540 of 587
# 	 Train Loss: 1.1982474327087402
# Beginning batch 550 of 587
# 	 Train Loss: 2.1611201763153076
# Beginning batch 560 of 587
# 	 Train Loss: 2.2112181186676025
# Beginning batch 570 of 587
# 	 Train Loss: 2.3377559185028076
# Beginning batch 580 of 587
# 	 Train Loss: 2.0728166103363037
# Testing batch 0
# 	 Test Loss: 2.200854539871216
# 	 Test Loss: 1.5746477842330933
# 	 Test Loss: 1.6989463567733765
# 	 Test Loss: 1.3863121271133423
# 	 Test Loss: 1.7984956502914429
# 	 Test Loss: 1.5865671634674072
# 	 Test Loss: 1.7556049823760986
# 	 Test Loss: 1.9016813039779663
# Beginning epoch 2
# Beginning batch 0 of 587
# 	 Train Loss: 1.5349000692367554
# Beginning batch 10 of 587
# 	 Train Loss: 1.3923979997634888
# Beginning batch 20 of 587
# 	 Train Loss: 1.6133800745010376
# Beginning batch 30 of 587
# 	 Train Loss: 1.0150320529937744
# Beginning batch 40 of 587
# 	 Train Loss: 1.5952264070510864
# Beginning batch 50 of 587
# 	 Train Loss: 1.6923630237579346
# Beginning batch 60 of 587
# 	 Train Loss: 1.1511147022247314
# Beginning batch 70 of 587
# 	 Train Loss: 2.3328399658203125
# Beginning batch 80 of 587
# 	 Train Loss: 1.600928544998169
# Beginning batch 90 of 587
# 	 Train Loss: 1.6373786926269531
# Beginning batch 100 of 587
# 	 Train Loss: 1.7141830921173096
# Beginning batch 110 of 587
# 	 Train Loss: 1.659948706626892
# Beginning batch 120 of 587
# 	 Train Loss: 1.4293893575668335
# Beginning batch 130 of 587
# 	 Train Loss: 1.8999427556991577
# Beginning batch 140 of 587
# 	 Train Loss: 1.7927265167236328
# Beginning batch 150 of 587
# 	 Train Loss: 1.7611777782440186
# Beginning batch 160 of 587
# 	 Train Loss: 1.7203929424285889
# Beginning batch 170 of 587
# 	 Train Loss: 1.769822120666504
# Beginning batch 180 of 587
# 	 Train Loss: 2.698540210723877
# Beginning batch 190 of 587
# 	 Train Loss: 1.3597346544265747
# Beginning batch 200 of 587
# 	 Train Loss: 1.5662791728973389
# Beginning batch 210 of 587
# 	 Train Loss: 0.9872142672538757
# Beginning batch 220 of 587
# 	 Train Loss: 1.6682043075561523
# Beginning batch 230 of 587
# 	 Train Loss: 1.8794214725494385
# Beginning batch 240 of 587
# 	 Train Loss: 1.5466465950012207
# Beginning batch 250 of 587
# 	 Train Loss: 1.8553402423858643
# Beginning batch 260 of 587
# 	 Train Loss: 1.479546308517456
# Beginning batch 270 of 587
# 	 Train Loss: 1.660750150680542
# Beginning batch 280 of 587
# 	 Train Loss: 1.7663538455963135
# Beginning batch 290 of 587
# 	 Train Loss: 1.7134315967559814
# Beginning batch 300 of 587
# 	 Train Loss: 1.6006309986114502
# Beginning batch 310 of 587
# 	 Train Loss: 1.4629251956939697
# Beginning batch 320 of 587
# 	 Train Loss: 1.442865252494812
# Beginning batch 330 of 587
# 	 Train Loss: 1.8084853887557983
# Beginning batch 340 of 587
# 	 Train Loss: 1.5540982484817505
# Beginning batch 350 of 587
# 	 Train Loss: 1.6492106914520264
# Beginning batch 360 of 587
# 	 Train Loss: 1.162577748298645
# Beginning batch 370 of 587
# 	 Train Loss: 2.206879138946533
# Beginning batch 380 of 587
# 	 Train Loss: 2.0121498107910156
# Beginning batch 390 of 587
# 	 Train Loss: 1.2382936477661133
# Beginning batch 400 of 587
# 	 Train Loss: 1.717487096786499
# Beginning batch 410 of 587
# 	 Train Loss: 1.2369849681854248
# Beginning batch 420 of 587
# 	 Train Loss: 1.6150121688842773
# Beginning batch 430 of 587
# 	 Train Loss: 2.13448166847229
# Beginning batch 440 of 587
# 	 Train Loss: 1.729623556137085
# Beginning batch 450 of 587
# 	 Train Loss: 1.103403925895691
# Beginning batch 460 of 587
# 	 Train Loss: 1.5139087438583374
# Beginning batch 470 of 587
# 	 Train Loss: 1.3069897890090942
# Beginning batch 480 of 587
# 	 Train Loss: 1.536144495010376
# Beginning batch 490 of 587
# 	 Train Loss: 1.6184784173965454
# Beginning batch 500 of 587
# 	 Train Loss: 2.4153122901916504
# Beginning batch 510 of 587
# 	 Train Loss: 1.9927423000335693
# Beginning batch 520 of 587
# 	 Train Loss: 1.4538065195083618
# Beginning batch 530 of 587
# 	 Train Loss: 1.5704209804534912
# Beginning batch 540 of 587
# 	 Train Loss: 1.7216161489486694
# Beginning batch 550 of 587
# 	 Train Loss: 1.406646490097046
# Beginning batch 560 of 587
# 	 Train Loss: 1.1170990467071533
# Beginning batch 570 of 587
# 	 Train Loss: 1.2616080045700073
# Beginning batch 580 of 587
# 	 Train Loss: 1.499420166015625
# Testing batch 0
# 	 Test Loss: 2.0033645629882812
# 	 Test Loss: 1.6004135608673096
# 	 Test Loss: 1.4059607982635498
# 	 Test Loss: 1.2647814750671387
# 	 Test Loss: 2.036882162094116
# 	 Test Loss: 1.6682380437850952
# 	 Test Loss: 1.5129436254501343
# 	 Test Loss: 1.7908575534820557
# Beginning epoch 3
# Beginning batch 0 of 587
# 	 Train Loss: 1.6138887405395508
# Beginning batch 10 of 587
# 	 Train Loss: 2.370847225189209
# Beginning batch 20 of 587
# 	 Train Loss: 1.5707671642303467
# Beginning batch 30 of 587
# 	 Train Loss: 1.3915722370147705
# Beginning batch 40 of 587
# 	 Train Loss: 1.6013820171356201
# Beginning batch 50 of 587
# 	 Train Loss: 1.624114751815796
# Beginning batch 60 of 587
# 	 Train Loss: 1.4171507358551025
# Beginning batch 70 of 587
# 	 Train Loss: 1.6929460763931274
# Beginning batch 80 of 587
# 	 Train Loss: 1.631007194519043
# Beginning batch 90 of 587
# 	 Train Loss: 1.430469274520874
# Beginning batch 100 of 587
# 	 Train Loss: 1.3661361932754517
# Beginning batch 110 of 587
# 	 Train Loss: 1.161293625831604
# Beginning batch 120 of 587
# 	 Train Loss: 1.1486308574676514
# Beginning batch 130 of 587
# 	 Train Loss: 1.2248778343200684
# Beginning batch 140 of 587
# 	 Train Loss: 1.0771725177764893
# Beginning batch 150 of 587
# 	 Train Loss: 1.3811566829681396
# Beginning batch 160 of 587
# 	 Train Loss: 1.9086357355117798
# Beginning batch 170 of 587
# 	 Train Loss: 1.8568490743637085
# Beginning batch 180 of 587
# 	 Train Loss: 1.4801863431930542
# Beginning batch 190 of 587
# 	 Train Loss: 2.0856032371520996
# Beginning batch 200 of 587
# 	 Train Loss: 1.375900387763977
# Beginning batch 210 of 587
# 	 Train Loss: 1.5701137781143188
# Beginning batch 220 of 587
# 	 Train Loss: 2.1217586994171143
# Beginning batch 230 of 587
# 	 Train Loss: 1.6143436431884766
# Beginning batch 240 of 587
# 	 Train Loss: 1.5655605792999268
# Beginning batch 250 of 587
# 	 Train Loss: 2.255323886871338
# Beginning batch 260 of 587
# 	 Train Loss: 1.444820523262024
# Beginning batch 270 of 587
# 	 Train Loss: 1.3565969467163086
# Beginning batch 280 of 587
# 	 Train Loss: 1.8400846719741821
# Beginning batch 290 of 587
# 	 Train Loss: 1.6899254322052002
# Beginning batch 300 of 587
# 	 Train Loss: 1.9695062637329102
# Beginning batch 310 of 587
# 	 Train Loss: 1.4899778366088867
# Beginning batch 320 of 587
# 	 Train Loss: 1.3106038570404053
# Beginning batch 330 of 587
# 	 Train Loss: 1.9591495990753174
# Beginning batch 340 of 587
# 	 Train Loss: 1.291267991065979
# Beginning batch 350 of 587
# 	 Train Loss: 1.375995397567749
# Beginning batch 360 of 587
# 	 Train Loss: 1.4170928001403809
# Beginning batch 370 of 587
# 	 Train Loss: 0.9562677145004272
# Beginning batch 380 of 587
# 	 Train Loss: 2.138049364089966
# Beginning batch 390 of 587
# 	 Train Loss: 1.8128979206085205
# Beginning batch 400 of 587
# 	 Train Loss: 1.6130889654159546
# Beginning batch 410 of 587
# 	 Train Loss: 1.2924306392669678
# Beginning batch 420 of 587
# 	 Train Loss: 1.9797914028167725
# Beginning batch 430 of 587
# 	 Train Loss: 1.444779634475708
# Beginning batch 440 of 587
# 	 Train Loss: 1.6486690044403076
# Beginning batch 450 of 587
# 	 Train Loss: 1.168384313583374
# Beginning batch 460 of 587
# 	 Train Loss: 1.4096946716308594
# Beginning batch 470 of 587
# 	 Train Loss: 1.7451574802398682
# Beginning batch 480 of 587
# 	 Train Loss: 1.3338974714279175
# Beginning batch 490 of 587
# 	 Train Loss: 1.5260241031646729
# Beginning batch 500 of 587
# 	 Train Loss: 1.477964162826538
# Beginning batch 510 of 587
# 	 Train Loss: 2.0359702110290527
# Beginning batch 520 of 587
# 	 Train Loss: 1.3297860622406006
# Beginning batch 530 of 587
# 	 Train Loss: 1.5243182182312012
# Beginning batch 540 of 587
# 	 Train Loss: 1.9314695596694946
# Beginning batch 550 of 587
# 	 Train Loss: 1.6260042190551758
# Beginning batch 560 of 587
# 	 Train Loss: 1.190425992012024
# Beginning batch 570 of 587
# 	 Train Loss: 1.5511596202850342
# Beginning batch 580 of 587
# 	 Train Loss: 1.6225852966308594
# Testing batch 0
# 	 Test Loss: 1.7380880117416382
# 	 Test Loss: 1.5711636543273926
# 	 Test Loss: 1.5514837503433228
# 	 Test Loss: 1.1176165342330933
# 	 Test Loss: 1.274554967880249
# 	 Test Loss: 1.5210901498794556
# 	 Test Loss: 1.5516365766525269
# 	 Test Loss: 1.7554702758789062
# Beginning epoch 4
# Beginning batch 0 of 587
# 	 Train Loss: 1.6026833057403564
# Beginning batch 10 of 587
# 	 Train Loss: 1.6612462997436523
# Beginning batch 20 of 587
# 	 Train Loss: 1.4603477716445923
# Beginning batch 30 of 587
# 	 Train Loss: 1.8360483646392822
# Beginning batch 40 of 587
# 	 Train Loss: 1.3990705013275146
# Beginning batch 50 of 587
# 	 Train Loss: 1.34783136844635
# Beginning batch 60 of 587
# 	 Train Loss: 1.5287096500396729
# Beginning batch 70 of 587
# 	 Train Loss: 1.5425758361816406
# Beginning batch 80 of 587
# 	 Train Loss: 1.788718819618225
# Beginning batch 90 of 587
# 	 Train Loss: 1.5919100046157837
# Beginning batch 100 of 587
# 	 Train Loss: 1.4978911876678467
# Beginning batch 110 of 587
# 	 Train Loss: 1.439319372177124
# Beginning batch 120 of 587
# 	 Train Loss: 1.6350675821304321
# Beginning batch 130 of 587
# 	 Train Loss: 1.5249192714691162
# Beginning batch 140 of 587
# 	 Train Loss: 1.7989909648895264
# Beginning batch 150 of 587
# 	 Train Loss: 1.5385332107543945
# Beginning batch 160 of 587
# 	 Train Loss: 1.4105304479599
# Beginning batch 170 of 587
# 	 Train Loss: 1.4683035612106323
# Beginning batch 180 of 587
# 	 Train Loss: 1.8468269109725952
# Beginning batch 190 of 587
# 	 Train Loss: 1.5585771799087524
# Beginning batch 200 of 587
# 	 Train Loss: 1.6745021343231201
# Beginning batch 210 of 587
# 	 Train Loss: 1.230388879776001
# Beginning batch 220 of 587
# 	 Train Loss: 1.9682306051254272
# Beginning batch 230 of 587
# 	 Train Loss: 1.8464205265045166
# Beginning batch 240 of 587
# 	 Train Loss: 1.0745737552642822
# Beginning batch 250 of 587
# 	 Train Loss: 1.3924061059951782
# Beginning batch 260 of 587
# 	 Train Loss: 1.2079323530197144
# Beginning batch 270 of 587
# 	 Train Loss: 1.9357728958129883
# Beginning batch 280 of 587
# 	 Train Loss: 1.9347953796386719
# Beginning batch 290 of 587
# 	 Train Loss: 1.3654029369354248
# Beginning batch 300 of 587
# 	 Train Loss: 1.1447392702102661
# Beginning batch 310 of 587
# 	 Train Loss: 1.5329794883728027
# Beginning batch 320 of 587
# 	 Train Loss: 1.7785695791244507
# Beginning batch 330 of 587
# 	 Train Loss: 1.5870015621185303
# Beginning batch 340 of 587
# 	 Train Loss: 1.6532255411148071
# Beginning batch 350 of 587
# 	 Train Loss: 1.4814982414245605
# Beginning batch 360 of 587
# 	 Train Loss: 1.7064716815948486
# Beginning batch 370 of 587
# 	 Train Loss: 1.4993945360183716
# Beginning batch 380 of 587
# 	 Train Loss: 1.6772701740264893
# Beginning batch 390 of 587
# 	 Train Loss: 1.8846962451934814
# Beginning batch 400 of 587
# 	 Train Loss: 1.645747423171997
# Beginning batch 410 of 587
# 	 Train Loss: 1.3063398599624634
# Beginning batch 420 of 587
# 	 Train Loss: 1.2802072763442993
# Beginning batch 430 of 587
# 	 Train Loss: 1.648593544960022
# Beginning batch 440 of 587
# 	 Train Loss: 1.4681124687194824
# Beginning batch 450 of 587
# 	 Train Loss: 1.4924609661102295
# Beginning batch 460 of 587
# 	 Train Loss: 1.548736572265625
# Beginning batch 470 of 587
# 	 Train Loss: 1.6394412517547607
# Beginning batch 480 of 587
# 	 Train Loss: 1.3845305442810059
# Beginning batch 490 of 587
# 	 Train Loss: 1.7874419689178467
# Beginning batch 500 of 587
# 	 Train Loss: 2.260450839996338
# Beginning batch 510 of 587
# 	 Train Loss: 1.6335012912750244
# Beginning batch 520 of 587
# 	 Train Loss: 1.4664721488952637
# Beginning batch 530 of 587
# 	 Train Loss: 1.3420374393463135
# Beginning batch 540 of 587
# 	 Train Loss: 1.5350592136383057
# Beginning batch 550 of 587
# 	 Train Loss: 1.253772497177124
# Beginning batch 560 of 587
# 	 Train Loss: 1.0887012481689453
# Beginning batch 570 of 587
# 	 Train Loss: 1.6480039358139038
# Beginning batch 580 of 587
# 	 Train Loss: 1.1106141805648804
# Testing batch 0
# 	 Test Loss: 1.6109821796417236
# 	 Test Loss: 1.7743536233901978
# 	 Test Loss: 1.5030344724655151
# 	 Test Loss: 1.023526906967163
# 	 Test Loss: 1.48282790184021
# 	 Test Loss: 1.4807307720184326
# 	 Test Loss: 1.7084333896636963
# 	 Test Loss: 1.6848127841949463
# Beginning epoch 5
# Beginning batch 0 of 587
# 	 Train Loss: 1.851183295249939
# Beginning batch 10 of 587
# 	 Train Loss: 1.2570607662200928
# Beginning batch 20 of 587
# 	 Train Loss: 1.8969638347625732
# Beginning batch 30 of 587
# 	 Train Loss: 0.8799219131469727
# Beginning batch 40 of 587
# 	 Train Loss: 1.5764105319976807
# Beginning batch 50 of 587
# 	 Train Loss: 1.2642954587936401
# Beginning batch 60 of 587
# 	 Train Loss: 1.0536446571350098
# Beginning batch 70 of 587
# 	 Train Loss: 1.338456630706787
# Beginning batch 80 of 587
# 	 Train Loss: 1.1563081741333008
# Beginning batch 90 of 587
# 	 Train Loss: 1.3989055156707764
# Beginning batch 100 of 587
# 	 Train Loss: 2.0269389152526855
# Beginning batch 110 of 587
# 	 Train Loss: 1.4643526077270508
# Beginning batch 120 of 587
# 	 Train Loss: 1.4174851179122925
# Beginning batch 130 of 587
# 	 Train Loss: 1.3896934986114502
# Beginning batch 140 of 587
# 	 Train Loss: 1.1426838636398315
# Beginning batch 150 of 587
# 	 Train Loss: 1.4885936975479126
# Beginning batch 160 of 587
# 	 Train Loss: 1.5579283237457275
# Beginning batch 170 of 587
# 	 Train Loss: 1.7668870687484741
# Beginning batch 180 of 587
# 	 Train Loss: 2.0743112564086914
# Beginning batch 190 of 587
# 	 Train Loss: 1.5120525360107422
# Beginning batch 200 of 587
# 	 Train Loss: 1.8607051372528076
# Beginning batch 210 of 587
# 	 Train Loss: 1.048777461051941
# Beginning batch 220 of 587
# 	 Train Loss: 1.5462286472320557
# Beginning batch 230 of 587
# 	 Train Loss: 1.4573384523391724
# Beginning batch 240 of 587
# 	 Train Loss: 1.5597763061523438
# Beginning batch 250 of 587
# 	 Train Loss: 1.4907925128936768
# Beginning batch 260 of 587
# 	 Train Loss: 1.738335371017456
# Beginning batch 270 of 587
# 	 Train Loss: 1.7399123907089233
# Beginning batch 280 of 587
# 	 Train Loss: 1.7261472940444946
# Beginning batch 290 of 587
# 	 Train Loss: 2.0941848754882812
# Beginning batch 300 of 587
# 	 Train Loss: 1.0903232097625732
# Beginning batch 310 of 587
# 	 Train Loss: 1.776715874671936
# Beginning batch 320 of 587
# 	 Train Loss: 1.485317587852478
# Beginning batch 330 of 587
# 	 Train Loss: 1.2574957609176636
# Beginning batch 340 of 587
# 	 Train Loss: 1.4749877452850342
# Beginning batch 350 of 587
# 	 Train Loss: 1.7802337408065796
# Beginning batch 360 of 587
# 	 Train Loss: 1.6205778121948242
# Beginning batch 370 of 587
# 	 Train Loss: 1.3393837213516235
# Beginning batch 380 of 587
# 	 Train Loss: 1.4119675159454346
# Beginning batch 390 of 587
# 	 Train Loss: 1.028965711593628
# Beginning batch 400 of 587
# 	 Train Loss: 1.5332061052322388
# Beginning batch 410 of 587
# 	 Train Loss: 1.5427112579345703
# Beginning batch 420 of 587
# 	 Train Loss: 1.8862444162368774
# Beginning batch 430 of 587
# 	 Train Loss: 1.7538683414459229
# Beginning batch 440 of 587
# 	 Train Loss: 1.6972875595092773
# Beginning batch 450 of 587
# 	 Train Loss: 1.4288303852081299
# Beginning batch 460 of 587
# 	 Train Loss: 1.4614498615264893
# Beginning batch 470 of 587
# 	 Train Loss: 1.6037085056304932
# Beginning batch 480 of 587
# 	 Train Loss: 1.3669579029083252
# Beginning batch 490 of 587
# 	 Train Loss: 1.2407147884368896
# Beginning batch 500 of 587
# 	 Train Loss: 1.430110216140747
# Beginning batch 510 of 587
# 	 Train Loss: 1.6997864246368408
# Beginning batch 520 of 587
# 	 Train Loss: 1.9288069009780884
# Beginning batch 530 of 587
# 	 Train Loss: 1.6085708141326904
# Beginning batch 540 of 587
# 	 Train Loss: 1.4445855617523193
# Beginning batch 550 of 587
# 	 Train Loss: 1.5315766334533691
# Beginning batch 560 of 587
# 	 Train Loss: 1.289520502090454
# Beginning batch 570 of 587
# 	 Train Loss: 1.3138377666473389
# Beginning batch 580 of 587
# 	 Train Loss: 1.483320951461792
# Testing batch 0
# 	 Test Loss: 1.5305092334747314
# 	 Test Loss: 1.3909437656402588
# 	 Test Loss: 1.4388039112091064
# 	 Test Loss: 1.0901600122451782
# 	 Test Loss: 1.2695090770721436
# 	 Test Loss: 1.376230239868164
# 	 Test Loss: 1.375785231590271
# 	 Test Loss: 1.6974369287490845
# Beginning epoch 6
# Beginning batch 0 of 587
# 	 Train Loss: 1.4433785676956177
# Beginning batch 10 of 587
# 	 Train Loss: 1.264012336730957
# Beginning batch 20 of 587
# 	 Train Loss: 1.7323884963989258
# Beginning batch 30 of 587
# 	 Train Loss: 1.7305301427841187
# Beginning batch 40 of 587
# 	 Train Loss: 1.5693682432174683
# Beginning batch 50 of 587
# 	 Train Loss: 1.831933617591858
# Beginning batch 60 of 587
# 	 Train Loss: 2.1391568183898926
# Beginning batch 70 of 587
# 	 Train Loss: 2.3228249549865723
# Beginning batch 80 of 587
# 	 Train Loss: 1.1857380867004395
# Beginning batch 90 of 587
# 	 Train Loss: 1.2344011068344116
# Beginning batch 100 of 587
# 	 Train Loss: 1.4888473749160767
# Beginning batch 110 of 587
# 	 Train Loss: 1.8331420421600342
# Beginning batch 120 of 587
# 	 Train Loss: 1.5432697534561157
# Beginning batch 130 of 587
# 	 Train Loss: 1.6396564245224
# Beginning batch 140 of 587
# 	 Train Loss: 1.8994871377944946
# Beginning batch 150 of 587
# 	 Train Loss: 1.8020538091659546
# Beginning batch 160 of 587
# 	 Train Loss: 2.0111422538757324
# Beginning batch 170 of 587
# 	 Train Loss: 2.1525673866271973
# Beginning batch 180 of 587
# 	 Train Loss: 1.7608026266098022
# Beginning batch 190 of 587
# 	 Train Loss: 1.4117485284805298
# Beginning batch 200 of 587
# 	 Train Loss: 1.2633740901947021
# Beginning batch 210 of 587
# 	 Train Loss: 1.2153198719024658
# Beginning batch 220 of 587
# 	 Train Loss: 1.4254734516143799
# Beginning batch 230 of 587
# 	 Train Loss: 1.8464418649673462
# Beginning batch 240 of 587
# 	 Train Loss: 1.75978684425354
# Beginning batch 250 of 587
# 	 Train Loss: 1.7665894031524658
# Beginning batch 260 of 587
# 	 Train Loss: 1.2195398807525635
# Beginning batch 270 of 587
# 	 Train Loss: 1.4842822551727295
# Beginning batch 280 of 587
# 	 Train Loss: 1.5445876121520996
# Beginning batch 290 of 587
# 	 Train Loss: 1.4972585439682007
# Beginning batch 300 of 587
# 	 Train Loss: 1.47100830078125
# Beginning batch 310 of 587
# 	 Train Loss: 1.2806259393692017
# Beginning batch 320 of 587
# 	 Train Loss: 1.8578014373779297
# Beginning batch 330 of 587
# 	 Train Loss: 1.4939504861831665
# Beginning batch 340 of 587
# 	 Train Loss: 1.690262794494629
# Beginning batch 350 of 587
# 	 Train Loss: 1.2240718603134155
# Beginning batch 360 of 587
# 	 Train Loss: 1.202228307723999
# Beginning batch 370 of 587
# 	 Train Loss: 1.222913384437561
# Beginning batch 380 of 587
# 	 Train Loss: 1.1913732290267944
# Beginning batch 390 of 587
# 	 Train Loss: 1.254150629043579
# Beginning batch 400 of 587
# 	 Train Loss: 1.9350694417953491
# Beginning batch 410 of 587
# 	 Train Loss: 1.4243485927581787
# Beginning batch 420 of 587
# 	 Train Loss: 1.536622405052185
# Beginning batch 430 of 587
# 	 Train Loss: 0.949841320514679
# Beginning batch 440 of 587
# 	 Train Loss: 1.403471827507019
# Beginning batch 450 of 587
# 	 Train Loss: 1.2997474670410156
# Beginning batch 460 of 587
# 	 Train Loss: 2.1162235736846924
# Beginning batch 470 of 587
# 	 Train Loss: 1.634042739868164
# Beginning batch 480 of 587
# 	 Train Loss: 1.531960129737854
# Beginning batch 490 of 587
# 	 Train Loss: 1.6525142192840576
# Beginning batch 500 of 587
# 	 Train Loss: 1.645207166671753
# Beginning batch 510 of 587
# 	 Train Loss: 1.4640817642211914
# Beginning batch 520 of 587
# 	 Train Loss: 1.2423686981201172
# Beginning batch 530 of 587
# 	 Train Loss: 1.4323046207427979
# Beginning batch 540 of 587
# 	 Train Loss: 1.8553762435913086
# Beginning batch 550 of 587
# 	 Train Loss: 1.7009721994400024
# Beginning batch 560 of 587
# 	 Train Loss: 1.8671958446502686
# Beginning batch 570 of 587
# 	 Train Loss: 1.2730920314788818
# Beginning batch 580 of 587
# 	 Train Loss: 1.4306795597076416
# Testing batch 0
# 	 Test Loss: 1.6069459915161133
# 	 Test Loss: 1.5168712139129639
# 	 Test Loss: 1.3807523250579834
# 	 Test Loss: 1.0698155164718628
# 	 Test Loss: 1.2387372255325317
# 	 Test Loss: 1.4540932178497314
# 	 Test Loss: 1.4310823678970337
# 	 Test Loss: 1.7176225185394287
# Beginning epoch 7
# Beginning batch 0 of 587
# 	 Train Loss: 1.3107075691223145
# Beginning batch 10 of 587
# 	 Train Loss: 1.6180365085601807
# Beginning batch 20 of 587
# 	 Train Loss: 1.3430769443511963
# Beginning batch 30 of 587
# 	 Train Loss: 2.133545160293579
# Beginning batch 40 of 587
# 	 Train Loss: 1.8208467960357666
# Beginning batch 50 of 587
# 	 Train Loss: 1.3044644594192505
# Beginning batch 60 of 587
# 	 Train Loss: 2.0989670753479004
# Beginning batch 70 of 587
# 	 Train Loss: 1.441571831703186
# Beginning batch 80 of 587
# 	 Train Loss: 1.7019649744033813
# Beginning batch 90 of 587
# 	 Train Loss: 1.4842356443405151
# Beginning batch 100 of 587
# 	 Train Loss: 1.3660070896148682
# Beginning batch 110 of 587
# 	 Train Loss: 0.9824486970901489
# Beginning batch 120 of 587
# 	 Train Loss: 1.1566905975341797
# Beginning batch 130 of 587
# 	 Train Loss: 1.7113239765167236
# Beginning batch 140 of 587
# 	 Train Loss: 1.7414560317993164
# Beginning batch 150 of 587
# 	 Train Loss: 2.0522706508636475
# Beginning batch 160 of 587
# 	 Train Loss: 1.3110716342926025
# Beginning batch 170 of 587
# 	 Train Loss: 1.5610206127166748
# Beginning batch 180 of 587
# 	 Train Loss: 1.032928466796875
# Beginning batch 190 of 587
# 	 Train Loss: 1.2351086139678955
# Beginning batch 200 of 587
# 	 Train Loss: 1.2507315874099731
# Beginning batch 210 of 587
# 	 Train Loss: 1.3327068090438843
# Beginning batch 220 of 587
# 	 Train Loss: 1.9145100116729736
# Beginning batch 230 of 587
# 	 Train Loss: 1.703226089477539
# Beginning batch 240 of 587
# 	 Train Loss: 1.1926805973052979
# Beginning batch 250 of 587
# 	 Train Loss: 1.4455592632293701
# Beginning batch 260 of 587
# 	 Train Loss: 1.5849921703338623
# Beginning batch 270 of 587
# 	 Train Loss: 1.339234471321106
# Beginning batch 280 of 587
# 	 Train Loss: 1.213639736175537
# Beginning batch 290 of 587
# 	 Train Loss: 1.2712397575378418
# Beginning batch 300 of 587
# 	 Train Loss: 1.813483476638794
# Beginning batch 310 of 587
# 	 Train Loss: 1.8738847970962524
# Beginning batch 320 of 587
# 	 Train Loss: 1.5146405696868896
# Beginning batch 330 of 587
# 	 Train Loss: 1.0189076662063599
# Beginning batch 340 of 587
# 	 Train Loss: 1.7721760272979736
# Beginning batch 350 of 587
# 	 Train Loss: 1.3783012628555298
# Beginning batch 360 of 587
# 	 Train Loss: 1.2880222797393799
# Beginning batch 370 of 587
# 	 Train Loss: 1.3808693885803223
# Beginning batch 380 of 587
# 	 Train Loss: 1.2086131572723389
# Beginning batch 390 of 587
# 	 Train Loss: 1.6675955057144165
# Beginning batch 400 of 587
# 	 Train Loss: 2.0546088218688965
# Beginning batch 410 of 587
# 	 Train Loss: 1.836005449295044
# Beginning batch 420 of 587
# 	 Train Loss: 1.451685905456543
# Beginning batch 430 of 587
# 	 Train Loss: 1.423755407333374
# Beginning batch 440 of 587
# 	 Train Loss: 1.296565055847168
# Beginning batch 450 of 587
# 	 Train Loss: 1.7085803747177124
# Beginning batch 460 of 587
# 	 Train Loss: 1.541896104812622
# Beginning batch 470 of 587
# 	 Train Loss: 1.331335425376892
# Beginning batch 480 of 587
# 	 Train Loss: 1.580944538116455
# Beginning batch 490 of 587
# 	 Train Loss: 1.1165908575057983
# Beginning batch 500 of 587
# 	 Train Loss: 1.282827615737915
# Beginning batch 510 of 587
# 	 Train Loss: 1.5521907806396484
# Beginning batch 520 of 587
# 	 Train Loss: 1.2445762157440186
# Beginning batch 530 of 587
# 	 Train Loss: 1.2926065921783447
# Beginning batch 540 of 587
# 	 Train Loss: 1.3386939764022827
# Beginning batch 550 of 587
# 	 Train Loss: 1.8134113550186157
# Beginning batch 560 of 587
# 	 Train Loss: 1.6695054769515991
# Beginning batch 570 of 587
# 	 Train Loss: 1.666142225265503
# Beginning batch 580 of 587
# 	 Train Loss: 1.837402105331421
# Testing batch 0
# 	 Test Loss: 1.6186106204986572
# 	 Test Loss: 1.5030256509780884
# 	 Test Loss: 1.3732244968414307
# 	 Test Loss: 1.1663645505905151
# 	 Test Loss: 1.3175297975540161
# 	 Test Loss: 1.622315764427185
# 	 Test Loss: 1.4197875261306763
# 	 Test Loss: 1.606986403465271
# Beginning epoch 8
# Beginning batch 0 of 587
# 	 Train Loss: 1.1762580871582031
# Beginning batch 10 of 587
# 	 Train Loss: 0.9599376916885376
# Beginning batch 20 of 587
# 	 Train Loss: 1.5271984338760376
# Beginning batch 30 of 587
# 	 Train Loss: 1.4350104331970215
# Beginning batch 40 of 587
# 	 Train Loss: 1.1666746139526367
# Beginning batch 50 of 587
# 	 Train Loss: 1.3666837215423584
# Beginning batch 60 of 587
# 	 Train Loss: 1.6939493417739868
# Beginning batch 70 of 587
# 	 Train Loss: 1.4141452312469482
# Beginning batch 80 of 587
# 	 Train Loss: 1.4280526638031006
# Beginning batch 90 of 587
# 	 Train Loss: 1.2809385061264038
# Beginning batch 100 of 587
# 	 Train Loss: 1.5085713863372803
# Beginning batch 110 of 587
# 	 Train Loss: 1.7220275402069092
# Beginning batch 120 of 587
# 	 Train Loss: 1.7188609838485718
# Beginning batch 130 of 587
# 	 Train Loss: 1.2314492464065552
# Beginning batch 140 of 587
# 	 Train Loss: 1.412867546081543
# Beginning batch 150 of 587
# 	 Train Loss: 1.7100002765655518
# Beginning batch 160 of 587
# 	 Train Loss: 1.5797784328460693
# Beginning batch 170 of 587
# 	 Train Loss: 0.9887455105781555
# Beginning batch 180 of 587
# 	 Train Loss: 1.0649147033691406
# Beginning batch 190 of 587
# 	 Train Loss: 1.0796953439712524
# Beginning batch 200 of 587
# 	 Train Loss: 1.0704330205917358
# Beginning batch 210 of 587
# 	 Train Loss: 1.2839670181274414
# Beginning batch 220 of 587
# 	 Train Loss: 1.2994180917739868
# Beginning batch 230 of 587
# 	 Train Loss: 1.410611867904663
# Beginning batch 240 of 587
# 	 Train Loss: 1.13080894947052
# Beginning batch 250 of 587
# 	 Train Loss: 1.7255544662475586
# Beginning batch 260 of 587
# 	 Train Loss: 1.6597617864608765
# Beginning batch 270 of 587
# 	 Train Loss: 1.6467187404632568
# Beginning batch 280 of 587
# 	 Train Loss: 1.4945353269577026
# Beginning batch 290 of 587
# 	 Train Loss: 1.2921571731567383
# Beginning batch 300 of 587
# 	 Train Loss: 1.6238610744476318
# Beginning batch 310 of 587
# 	 Train Loss: 1.3598252534866333
# Beginning batch 320 of 587
# 	 Train Loss: 1.167473316192627
# Beginning batch 330 of 587
# 	 Train Loss: 1.4092226028442383
# Beginning batch 340 of 587
# 	 Train Loss: 1.6049840450286865
# Beginning batch 350 of 587
# 	 Train Loss: 1.513772964477539
# Beginning batch 360 of 587
# 	 Train Loss: 1.0079435110092163
# Beginning batch 370 of 587
# 	 Train Loss: 2.0577428340911865
# Beginning batch 380 of 587
# 	 Train Loss: 1.2605892419815063
# Beginning batch 390 of 587
# 	 Train Loss: 1.7838056087493896
# Beginning batch 400 of 587
# 	 Train Loss: 1.4866591691970825
# Beginning batch 410 of 587
# 	 Train Loss: 1.311753511428833
# Beginning batch 420 of 587
# 	 Train Loss: 1.204227328300476
# Beginning batch 430 of 587
# 	 Train Loss: 1.4544926881790161
# Beginning batch 440 of 587
# 	 Train Loss: 1.269439935684204
# Beginning batch 450 of 587
# 	 Train Loss: 1.3601114749908447
# Beginning batch 460 of 587
# 	 Train Loss: 1.318129539489746
# Beginning batch 470 of 587
# 	 Train Loss: 1.80038321018219
# Beginning batch 480 of 587
# 	 Train Loss: 1.5499359369277954
# Beginning batch 490 of 587
# 	 Train Loss: 1.9451249837875366
# Beginning batch 500 of 587
# 	 Train Loss: 1.0899913311004639
# Beginning batch 510 of 587
# 	 Train Loss: 1.6846587657928467
# Beginning batch 520 of 587
# 	 Train Loss: 1.9547603130340576
# Beginning batch 530 of 587
# 	 Train Loss: 1.4680287837982178
# Beginning batch 540 of 587
# 	 Train Loss: 2.6426055431365967
# Beginning batch 550 of 587
# 	 Train Loss: 1.8036022186279297
# Beginning batch 560 of 587
# 	 Train Loss: 1.1315592527389526
# Beginning batch 570 of 587
# 	 Train Loss: 1.2198065519332886
# Beginning batch 580 of 587
# 	 Train Loss: 1.0760606527328491
# Testing batch 0
# 	 Test Loss: 1.4943193197250366
# 	 Test Loss: 1.3838990926742554
# 	 Test Loss: 1.2634586095809937
# 	 Test Loss: 1.0109121799468994
# 	 Test Loss: 1.2290704250335693
# 	 Test Loss: 1.5575838088989258
# 	 Test Loss: 1.4723196029663086
# 	 Test Loss: 1.4867465496063232
# Beginning epoch 9
# Beginning batch 0 of 587
# 	 Train Loss: 1.8016691207885742
# Beginning batch 10 of 587
# 	 Train Loss: 1.1727405786514282
# Beginning batch 20 of 587
# 	 Train Loss: 1.6330198049545288
# Beginning batch 30 of 587
# 	 Train Loss: 1.2617435455322266
# Beginning batch 40 of 587
# 	 Train Loss: 1.7887332439422607
# Beginning batch 50 of 587
# 	 Train Loss: 1.3848096132278442
# Beginning batch 60 of 587
# 	 Train Loss: 1.6628538370132446
# Beginning batch 70 of 587
# 	 Train Loss: 1.1768715381622314
# Beginning batch 80 of 587
# 	 Train Loss: 1.6626077890396118
# Beginning batch 90 of 587
# 	 Train Loss: 1.6609821319580078
# Beginning batch 100 of 587
# 	 Train Loss: 1.563466191291809
# Beginning batch 110 of 587
# 	 Train Loss: 1.4045594930648804
# Beginning batch 120 of 587
# 	 Train Loss: 1.3509947061538696
# Beginning batch 130 of 587
# 	 Train Loss: 1.2228859663009644
# Beginning batch 140 of 587
# 	 Train Loss: 1.5144217014312744
# Beginning batch 150 of 587
# 	 Train Loss: 2.325598955154419
# Beginning batch 160 of 587
# 	 Train Loss: 1.401790738105774
# Beginning batch 170 of 587
# 	 Train Loss: 1.2770421504974365
# Beginning batch 180 of 587
# 	 Train Loss: 1.5083909034729004
# Beginning batch 190 of 587
# 	 Train Loss: 1.4836803674697876
# Beginning batch 200 of 587
# 	 Train Loss: 1.038454294204712
# Beginning batch 210 of 587
# 	 Train Loss: 0.8937065005302429
# Beginning batch 220 of 587
# 	 Train Loss: 1.6298789978027344
# Beginning batch 230 of 587
# 	 Train Loss: 1.5084683895111084
# Beginning batch 240 of 587
# 	 Train Loss: 1.744545340538025
# Beginning batch 250 of 587
# 	 Train Loss: 1.6448028087615967
# Beginning batch 260 of 587
# 	 Train Loss: 2.043748378753662
# Beginning batch 270 of 587
# 	 Train Loss: 1.3262245655059814
# Beginning batch 280 of 587
# 	 Train Loss: 1.63808274269104
# Beginning batch 290 of 587
# 	 Train Loss: 1.4918121099472046
# Beginning batch 300 of 587
# 	 Train Loss: 1.156040072441101
# Beginning batch 310 of 587
# 	 Train Loss: 1.1076267957687378
# Beginning batch 320 of 587
# 	 Train Loss: 1.2605993747711182
# Beginning batch 330 of 587
# 	 Train Loss: 1.796640396118164
# Beginning batch 340 of 587
# 	 Train Loss: 1.2107012271881104
# Beginning batch 350 of 587
# 	 Train Loss: 1.227213740348816
# Beginning batch 360 of 587
# 	 Train Loss: 1.3691205978393555
# Beginning batch 370 of 587
# 	 Train Loss: 1.9024311304092407
# Beginning batch 380 of 587
# 	 Train Loss: 1.402996301651001
# Beginning batch 390 of 587
# 	 Train Loss: 1.3924740552902222
# Beginning batch 400 of 587
# 	 Train Loss: 1.5146186351776123
# Beginning batch 410 of 587
# 	 Train Loss: 1.302951455116272
# Beginning batch 420 of 587
# 	 Train Loss: 1.1276167631149292
# Beginning batch 430 of 587
# 	 Train Loss: 1.1869680881500244
# Beginning batch 440 of 587
# 	 Train Loss: 1.4520456790924072
# Beginning batch 450 of 587
# 	 Train Loss: 0.9509768486022949
# Beginning batch 460 of 587
# 	 Train Loss: 1.6432220935821533
# Beginning batch 470 of 587
# 	 Train Loss: 1.9162877798080444
# Beginning batch 480 of 587
# 	 Train Loss: 1.4860776662826538
# Beginning batch 490 of 587
# 	 Train Loss: 2.043123722076416
# Beginning batch 500 of 587
# 	 Train Loss: 1.3344519138336182
# Beginning batch 510 of 587
# 	 Train Loss: 1.2898049354553223
# Beginning batch 520 of 587
# 	 Train Loss: 1.2930269241333008
# Beginning batch 530 of 587
# 	 Train Loss: 1.3694658279418945
# Beginning batch 540 of 587
# 	 Train Loss: 0.8811519742012024
# Beginning batch 550 of 587
# 	 Train Loss: 1.5071499347686768
# Beginning batch 560 of 587
# 	 Train Loss: 1.8458541631698608
# Beginning batch 570 of 587
# 	 Train Loss: 1.6081466674804688
# Beginning batch 580 of 587
# 	 Train Loss: 1.2845466136932373
# Testing batch 0
# 	 Test Loss: 1.5699462890625
# 	 Test Loss: 1.456350564956665
# 	 Test Loss: 1.412071704864502
# 	 Test Loss: 1.0665050745010376
# 	 Test Loss: 1.244828224182129
# 	 Test Loss: 1.4307200908660889
# 	 Test Loss: 1.2962404489517212
# 	 Test Loss: 1.8534799814224243
# Beginning epoch 10
# Beginning batch 0 of 587
# 	 Train Loss: 1.2975308895111084
# Beginning batch 10 of 587
# 	 Train Loss: 1.7487335205078125
# Beginning batch 20 of 587
# 	 Train Loss: 1.5621341466903687
# Beginning batch 30 of 587
# 	 Train Loss: 1.7427809238433838
# Beginning batch 40 of 587
# 	 Train Loss: 1.6711480617523193
# Beginning batch 50 of 587
# 	 Train Loss: 1.1827080249786377
# Beginning batch 60 of 587
# 	 Train Loss: 1.135835886001587
# Beginning batch 70 of 587
# 	 Train Loss: 1.4468196630477905
# Beginning batch 80 of 587
# 	 Train Loss: 1.467848300933838
# Beginning batch 90 of 587
# 	 Train Loss: 1.5755770206451416
# Beginning batch 100 of 587
# 	 Train Loss: 1.2562521696090698
# Beginning batch 110 of 587
# 	 Train Loss: 1.189981460571289
# Beginning batch 120 of 587
# 	 Train Loss: 1.16364324092865
# Beginning batch 130 of 587
# 	 Train Loss: 1.2401621341705322
# Beginning batch 140 of 587
# 	 Train Loss: 1.5882256031036377
# Beginning batch 150 of 587
# 	 Train Loss: 1.3230760097503662
# Beginning batch 160 of 587
# 	 Train Loss: 1.5886894464492798
# Beginning batch 170 of 587
# 	 Train Loss: 1.3066816329956055
# Beginning batch 180 of 587
# 	 Train Loss: 1.2284172773361206
# Beginning batch 190 of 587
# 	 Train Loss: 1.7683517932891846
# Beginning batch 200 of 587
# 	 Train Loss: 1.2658296823501587
# Beginning batch 210 of 587
# 	 Train Loss: 1.3776986598968506
# Beginning batch 220 of 587
# 	 Train Loss: 1.4707871675491333
# Beginning batch 230 of 587
# 	 Train Loss: 2.0130324363708496
# Beginning batch 240 of 587
# 	 Train Loss: 1.2410383224487305
# Beginning batch 250 of 587
# 	 Train Loss: 1.6201032400131226
# Beginning batch 260 of 587
# 	 Train Loss: 1.2970681190490723
# Beginning batch 270 of 587
# 	 Train Loss: 1.1970417499542236
# Beginning batch 280 of 587
# 	 Train Loss: 1.3665273189544678
# Beginning batch 290 of 587
# 	 Train Loss: 1.4638055562973022
# Beginning batch 300 of 587
# 	 Train Loss: 1.3074581623077393
# Beginning batch 310 of 587
# 	 Train Loss: 2.553393602371216
# Beginning batch 320 of 587
# 	 Train Loss: 1.2599247694015503
# Beginning batch 330 of 587
# 	 Train Loss: 1.3338664770126343
# Beginning batch 340 of 587
# 	 Train Loss: 1.4837830066680908
# Beginning batch 350 of 587
# 	 Train Loss: 1.5118216276168823
# Beginning batch 360 of 587
# 	 Train Loss: 1.4404339790344238
# Beginning batch 370 of 587
# 	 Train Loss: 1.8433239459991455
# Beginning batch 380 of 587
# 	 Train Loss: 1.5884068012237549
# Beginning batch 390 of 587
# 	 Train Loss: 1.4352879524230957
# Beginning batch 400 of 587
# 	 Train Loss: 1.3917691707611084
# Beginning batch 410 of 587
# 	 Train Loss: 1.16640305519104
# Beginning batch 420 of 587
# 	 Train Loss: 1.9939186573028564
# Beginning batch 430 of 587
# 	 Train Loss: 1.1716454029083252
# Beginning batch 440 of 587
# 	 Train Loss: 1.5267536640167236
# Beginning batch 450 of 587
# 	 Train Loss: 1.5821282863616943
# Beginning batch 460 of 587
# 	 Train Loss: 1.4446985721588135
# Beginning batch 470 of 587
# 	 Train Loss: 1.6144208908081055
# Beginning batch 480 of 587
# 	 Train Loss: 0.9212946891784668
# Beginning batch 490 of 587
# 	 Train Loss: 1.2027956247329712
# Beginning batch 500 of 587
# 	 Train Loss: 1.1283113956451416
# Beginning batch 510 of 587
# 	 Train Loss: 1.6940994262695312
# Beginning batch 520 of 587
# 	 Train Loss: 1.3152105808258057
# Beginning batch 530 of 587
# 	 Train Loss: 1.1020580530166626
# Beginning batch 540 of 587
# 	 Train Loss: 1.5606958866119385
# Beginning batch 550 of 587
# 	 Train Loss: 1.025335669517517
# Beginning batch 560 of 587
# 	 Train Loss: 1.370862364768982
# Beginning batch 570 of 587
# 	 Train Loss: 1.6517823934555054
# Beginning batch 580 of 587
# 	 Train Loss: 1.6501413583755493
# Testing batch 0
# 	 Test Loss: 1.5016298294067383
# 	 Test Loss: 1.4450676441192627
# 	 Test Loss: 1.5634682178497314
# 	 Test Loss: 0.9716499447822571
# 	 Test Loss: 1.5591297149658203
# 	 Test Loss: 1.5023095607757568
# 	 Test Loss: 1.4350221157073975
# 	 Test Loss: 1.6551437377929688
# Beginning epoch 11
# Beginning batch 0 of 587
# 	 Train Loss: 1.2481011152267456
# Beginning batch 10 of 587
# 	 Train Loss: 1.4710559844970703
# Beginning batch 20 of 587
# 	 Train Loss: 0.8697409629821777
# Beginning batch 30 of 587
# 	 Train Loss: 1.2280209064483643
# Beginning batch 40 of 587
# 	 Train Loss: 1.3203635215759277
# Beginning batch 50 of 587
# 	 Train Loss: 1.262604832649231
# Beginning batch 60 of 587
# 	 Train Loss: 1.5403951406478882
# Beginning batch 70 of 587
# 	 Train Loss: 1.281287670135498
# Beginning batch 80 of 587
# 	 Train Loss: 1.3471159934997559
# Beginning batch 90 of 587
# 	 Train Loss: 1.2301685810089111
# Beginning batch 100 of 587
# 	 Train Loss: 1.1073908805847168
# Beginning batch 110 of 587
# 	 Train Loss: 1.2924625873565674
# Beginning batch 120 of 587
# 	 Train Loss: 1.23097562789917
# Beginning batch 130 of 587
# 	 Train Loss: 1.6597557067871094
# Beginning batch 140 of 587
# 	 Train Loss: 1.503462553024292
# Beginning batch 150 of 587
# 	 Train Loss: 1.16025710105896
# Beginning batch 160 of 587
# 	 Train Loss: 1.4856685400009155
# Beginning batch 170 of 587
# 	 Train Loss: 1.6967426538467407
# Beginning batch 180 of 587
# 	 Train Loss: 1.2541817426681519
# Beginning batch 190 of 587
# 	 Train Loss: 1.1584751605987549
# Beginning batch 200 of 587
# 	 Train Loss: 1.2885189056396484
# Beginning batch 210 of 587
# 	 Train Loss: 0.9752252697944641
# Beginning batch 220 of 587
# 	 Train Loss: 1.718772292137146
# Beginning batch 230 of 587
# 	 Train Loss: 1.1091843843460083
# Beginning batch 240 of 587
# 	 Train Loss: 1.6477454900741577
# Beginning batch 250 of 587
# 	 Train Loss: 1.428086757659912
# Beginning batch 260 of 587
# 	 Train Loss: 1.4236881732940674
# Beginning batch 270 of 587
# 	 Train Loss: 1.4603108167648315
# Beginning batch 280 of 587
# 	 Train Loss: 1.1554020643234253
# Beginning batch 290 of 587
# 	 Train Loss: 1.523163080215454
# Beginning batch 300 of 587
# 	 Train Loss: 1.1076605319976807
# Beginning batch 310 of 587
# 	 Train Loss: 1.7782033681869507
# Beginning batch 320 of 587
# 	 Train Loss: 1.140618085861206
# Beginning batch 330 of 587
# 	 Train Loss: 1.365238070487976
# Beginning batch 340 of 587
# 	 Train Loss: 1.1051783561706543
# Beginning batch 350 of 587
# 	 Train Loss: 1.3632123470306396
# Beginning batch 360 of 587
# 	 Train Loss: 1.307780385017395
# Beginning batch 370 of 587
# 	 Train Loss: 1.327909231185913
# Beginning batch 380 of 587
# 	 Train Loss: 1.2916196584701538
# Beginning batch 390 of 587
# 	 Train Loss: 1.39303719997406
# Beginning batch 400 of 587
# 	 Train Loss: 0.8590946197509766
# Beginning batch 410 of 587
# 	 Train Loss: 1.5722328424453735
# Beginning batch 420 of 587
# 	 Train Loss: 1.0740116834640503
# Beginning batch 430 of 587
# 	 Train Loss: 1.3188822269439697
# Beginning batch 440 of 587
# 	 Train Loss: 1.4449232816696167
# Beginning batch 450 of 587
# 	 Train Loss: 1.241633653640747
# Beginning batch 460 of 587
# 	 Train Loss: 1.4244357347488403
# Beginning batch 470 of 587
# 	 Train Loss: 1.2452034950256348
# Beginning batch 480 of 587
# 	 Train Loss: 1.5643219947814941
# Beginning batch 490 of 587
# 	 Train Loss: 1.1561636924743652
# Beginning batch 500 of 587
# 	 Train Loss: 1.4780933856964111
# Beginning batch 510 of 587
# 	 Train Loss: 1.8455030918121338
# Beginning batch 520 of 587
# 	 Train Loss: 1.6748758554458618
# Beginning batch 530 of 587
# 	 Train Loss: 1.6473476886749268
# Beginning batch 540 of 587
# 	 Train Loss: 1.2935569286346436
# Beginning batch 550 of 587
# 	 Train Loss: 1.0979896783828735
# Beginning batch 560 of 587
# 	 Train Loss: 1.4501246213912964
# Beginning batch 570 of 587
# 	 Train Loss: 1.326148509979248
# Beginning batch 580 of 587
# 	 Train Loss: 1.3114287853240967
# Testing batch 0
# 	 Test Loss: 1.698840856552124
# 	 Test Loss: 1.5069143772125244
# 	 Test Loss: 1.3541148900985718
# 	 Test Loss: 0.9503422975540161
# 	 Test Loss: 1.0242769718170166
# 	 Test Loss: 1.4930286407470703
# 	 Test Loss: 1.491849660873413
# 	 Test Loss: 1.6553361415863037
# Beginning epoch 12
# Beginning batch 0 of 587
# 	 Train Loss: 1.6115739345550537
# Beginning batch 10 of 587
# 	 Train Loss: 1.9656667709350586
# Beginning batch 20 of 587
# 	 Train Loss: 1.328938364982605
# Beginning batch 30 of 587
# 	 Train Loss: 0.9471861124038696
# Beginning batch 40 of 587
# 	 Train Loss: 1.214645266532898
# Beginning batch 50 of 587
# 	 Train Loss: 1.5140197277069092
# Beginning batch 60 of 587
# 	 Train Loss: 1.2228361368179321
# Beginning batch 70 of 587
# 	 Train Loss: 1.4133236408233643
# Beginning batch 80 of 587
# 	 Train Loss: 0.9894536137580872
# Beginning batch 90 of 587
# 	 Train Loss: 1.0531318187713623
# Beginning batch 100 of 587
# 	 Train Loss: 1.3236063718795776
# Beginning batch 110 of 587
# 	 Train Loss: 1.178539514541626
# Beginning batch 120 of 587
# 	 Train Loss: 1.065665602684021
# Beginning batch 130 of 587
# 	 Train Loss: 1.379424810409546
# Beginning batch 140 of 587
# 	 Train Loss: 1.3169422149658203
# Beginning batch 150 of 587
# 	 Train Loss: 1.4661343097686768
# Beginning batch 160 of 587
# 	 Train Loss: 2.2396931648254395
# Beginning batch 170 of 587
# 	 Train Loss: 1.5213251113891602
# Beginning batch 180 of 587
# 	 Train Loss: 1.7417646646499634
# Beginning batch 190 of 587
# 	 Train Loss: 1.272689700126648
# Beginning batch 200 of 587
# 	 Train Loss: 1.2622246742248535
# Beginning batch 210 of 587
# 	 Train Loss: 1.240572214126587
# Beginning batch 220 of 587
# 	 Train Loss: 1.4997272491455078
# Beginning batch 230 of 587
# 	 Train Loss: 1.660112738609314
# Beginning batch 240 of 587
# 	 Train Loss: 1.554792881011963
# Beginning batch 250 of 587
# 	 Train Loss: 1.2887547016143799
# Beginning batch 260 of 587
# 	 Train Loss: 1.4516313076019287
# Beginning batch 270 of 587
# 	 Train Loss: 1.4908397197723389
# Beginning batch 280 of 587
# 	 Train Loss: 1.6716314554214478
# Beginning batch 290 of 587
# 	 Train Loss: 1.5451630353927612
# Beginning batch 300 of 587
# 	 Train Loss: 1.426584005355835
# Beginning batch 310 of 587
# 	 Train Loss: 1.8260078430175781
# Beginning batch 320 of 587
# 	 Train Loss: 1.1796388626098633
# Beginning batch 330 of 587
# 	 Train Loss: 1.177424430847168
# Beginning batch 340 of 587
# 	 Train Loss: 1.373995065689087
# Beginning batch 350 of 587
# 	 Train Loss: 1.4673430919647217
# Beginning batch 360 of 587
# 	 Train Loss: 1.404755711555481
# Beginning batch 370 of 587
# 	 Train Loss: 1.2071417570114136
# Beginning batch 380 of 587
# 	 Train Loss: 1.2786298990249634
# Beginning batch 390 of 587
# ...
# Beginning batch 70 of 587
# 	 Train Loss: 0.9220491647720337
# Beginning batch 80 of 587
# 	 Train Loss: 1.0925981998443604
# Beginning batch 90 of 587
# 	 Train Loss: 1.8213402032852173
# Beginning batch 100 of 587
# 	 Train Loss: 1.7393783330917358
# Beginning batch 110 of 587
# 	 Train Loss: 0.9319823384284973
# Beginning batch 120 of 587
# 	 Train Loss: 1.0689772367477417
# Beginning batch 130 of 587
# 	 Train Loss: 1.1900571584701538
# Beginning batch 140 of 587
# 	 Train Loss: 1.754863977432251
# Beginning batch 150 of 587
# 	 Train Loss: 0.7503495812416077
# Beginning batch 160 of 587
# 	 Train Loss: 1.1315922737121582
# Beginning batch 170 of 587
# 	 Train Loss: 1.5587915182113647
# Beginning batch 180 of 587
# 	 Train Loss: 0.7874693274497986
# Beginning batch 190 of 587
# 	 Train Loss: 1.3849085569381714
# Beginning batch 200 of 587
# 	 Train Loss: 1.122332215309143
# Beginning batch 210 of 587
# 	 Train Loss: 1.0910437107086182
# Beginning batch 220 of 587
# 	 Train Loss: 1.3215616941452026
# Beginning batch 230 of 587
# 	 Train Loss: 0.8292856216430664
# Beginning batch 240 of 587
# 	 Train Loss: 1.3088786602020264
# Beginning batch 250 of 587
# 	 Train Loss: 1.4228179454803467
# Beginning batch 260 of 587
# 	 Train Loss: 1.3064186573028564
# Beginning batch 270 of 587
# 	 Train Loss: 1.3351088762283325
# Beginning batch 280 of 587
# 	 Train Loss: 1.2006055116653442
# Beginning batch 290 of 587
# 	 Train Loss: 0.9674709439277649
# Beginning batch 300 of 587
# 	 Train Loss: 1.0334266424179077
# Beginning batch 310 of 587
# 	 Train Loss: 1.3782579898834229
# Beginning batch 320 of 587
# 	 Train Loss: 1.802321195602417
# Beginning batch 330 of 587
# 	 Train Loss: 1.413080096244812
# Beginning batch 340 of 587
# 	 Train Loss: 1.399188756942749
# Beginning batch 350 of 587
# 	 Train Loss: 1.4097412824630737
# Beginning batch 360 of 587
# 	 Train Loss: 1.798583984375
# Beginning batch 370 of 587
# 	 Train Loss: 0.9849843978881836
# Beginning batch 380 of 587
# 	 Train Loss: 1.3450818061828613
# Beginning batch 390 of 587
# 	 Train Loss: 0.8692519068717957
# Beginning batch 400 of 587
# 	 Train Loss: 1.2944653034210205
# Beginning batch 410 of 587
# 	 Train Loss: 1.2348601818084717
# Beginning batch 420 of 587
# 	 Train Loss: 1.0726196765899658
# Beginning batch 430 of 587
# 	 Train Loss: 1.1139520406723022
# Beginning batch 440 of 587
# 	 Train Loss: 1.2926675081253052
# Beginning batch 450 of 587
# 	 Train Loss: 1.17100989818573
# Beginning batch 460 of 587
# 	 Train Loss: 1.3108960390090942
# Beginning batch 470 of 587
# 	 Train Loss: 1.1443474292755127
# Beginning batch 480 of 587
# 	 Train Loss: 1.0383081436157227
# Beginning batch 490 of 587
# 	 Train Loss: 1.080202341079712
# Beginning batch 500 of 587
# 	 Train Loss: 1.9347985982894897
# Beginning batch 510 of 587
# 	 Train Loss: 0.804222583770752
# Beginning batch 520 of 587
# 	 Train Loss: 1.1986324787139893
# Beginning batch 530 of 587
# 	 Train Loss: 1.5078214406967163
# Beginning batch 540 of 587
# 	 Train Loss: 1.559545636177063
# Beginning batch 550 of 587
# 	 Train Loss: 1.5367988348007202
# Beginning batch 560 of 587
# 	 Train Loss: 1.1923611164093018
# Beginning batch 570 of 587
# 	 Train Loss: 0.8408232927322388
# Beginning batch 580 of 587
# 	 Train Loss: 1.0621275901794434
# Testing batch 0
# 	 Test Loss: 1.3243683576583862
# 	 Test Loss: 1.331311583518982
# 	 Test Loss: 1.2432841062545776
# 	 Test Loss: 0.9435303807258606
# 	 Test Loss: 0.9137991666793823
# 	 Test Loss: 1.340679407119751
# 	 Test Loss: 1.3412073850631714
# 	 Test Loss: 1.5834605693817139
# Beginning epoch 82
# Beginning batch 0 of 587
# 	 Train Loss: 0.962731659412384
# Beginning batch 10 of 587
# 	 Train Loss: 0.9469308853149414
# Beginning batch 20 of 587
# 	 Train Loss: 1.092597246170044
# Beginning batch 30 of 587
# 	 Train Loss: 1.4654619693756104
# Beginning batch 40 of 587
# 	 Train Loss: 1.162904143333435
# Beginning batch 50 of 587
# 	 Train Loss: 0.7582869529724121
# Beginning batch 60 of 587
# 	 Train Loss: 1.3607971668243408
# Beginning batch 70 of 587
# 	 Train Loss: 1.7927210330963135
# Beginning batch 80 of 587
# 	 Train Loss: 1.1341251134872437
# Beginning batch 90 of 587
# 	 Train Loss: 1.6097877025604248
# Beginning batch 100 of 587
# 	 Train Loss: 1.4900143146514893
# Beginning batch 110 of 587
# 	 Train Loss: 1.2026312351226807
# Beginning batch 120 of 587
# 	 Train Loss: 1.4086899757385254
# Beginning batch 130 of 587
# 	 Train Loss: 1.5017634630203247
# Beginning batch 140 of 587
# 	 Train Loss: 1.2107372283935547
# Beginning batch 150 of 587
# 	 Train Loss: 1.1174962520599365
# Beginning batch 160 of 587
# 	 Train Loss: 0.7334141135215759
# Beginning batch 170 of 587
# 	 Train Loss: 1.5245805978775024
# Beginning batch 180 of 587
# 	 Train Loss: 1.696672797203064
# Beginning batch 190 of 587
# 	 Train Loss: 1.0876084566116333
# Beginning batch 200 of 587
# 	 Train Loss: 1.121416687965393
# Beginning batch 210 of 587
# 	 Train Loss: 1.631018877029419
# Beginning batch 220 of 587
# 	 Train Loss: 1.6079254150390625
# Beginning batch 230 of 587
# 	 Train Loss: 1.2752659320831299
# Beginning batch 240 of 587
# 	 Train Loss: 0.8306798934936523
# Beginning batch 250 of 587
# 	 Train Loss: 1.2033703327178955
# Beginning batch 260 of 587
# 	 Train Loss: 1.0893523693084717
# Beginning batch 270 of 587
# 	 Train Loss: 1.1811723709106445
# Beginning batch 280 of 587
# 	 Train Loss: 1.8021005392074585
# Beginning batch 290 of 587
# 	 Train Loss: 1.2072099447250366
# Beginning batch 300 of 587
# 	 Train Loss: 0.8511332273483276
# Beginning batch 310 of 587
# 	 Train Loss: 0.9218143224716187
# Beginning batch 320 of 587
# 	 Train Loss: 1.38051438331604
# Beginning batch 330 of 587
# 	 Train Loss: 1.1856797933578491
# Beginning batch 340 of 587
# 	 Train Loss: 1.197625756263733
# Beginning batch 350 of 587
# 	 Train Loss: 1.0424673557281494
# Beginning batch 360 of 587
# 	 Train Loss: 1.3049545288085938
# Beginning batch 370 of 587
# 	 Train Loss: 1.5818713903427124
# Beginning batch 380 of 587
# 	 Train Loss: 0.8328539133071899
# Beginning batch 390 of 587
# 	 Train Loss: 0.9442439079284668
# Beginning batch 400 of 587
# 	 Train Loss: 1.1329702138900757
# Beginning batch 410 of 587
# 	 Train Loss: 1.1135326623916626
# Beginning batch 420 of 587
# 	 Train Loss: 1.0776768922805786
# Beginning batch 430 of 587
# 	 Train Loss: 0.6744595766067505
# Beginning batch 440 of 587
# 	 Train Loss: 0.8123407363891602
# Beginning batch 450 of 587
# 	 Train Loss: 0.9447242021560669
# Beginning batch 460 of 587
# 	 Train Loss: 0.9535461664199829
# Beginning batch 470 of 587
# 	 Train Loss: 0.8112622499465942
# Beginning batch 480 of 587
# 	 Train Loss: 1.1954562664031982
# Beginning batch 490 of 587
# 	 Train Loss: 1.5559799671173096
# Beginning batch 500 of 587
# 	 Train Loss: 1.259665846824646
# Beginning batch 510 of 587
# 	 Train Loss: 1.0578217506408691
# Beginning batch 520 of 587
# 	 Train Loss: 1.101654291152954
# Beginning batch 530 of 587
# 	 Train Loss: 0.9055744409561157
# Beginning batch 540 of 587
# 	 Train Loss: 1.0383961200714111
# Beginning batch 550 of 587
# 	 Train Loss: 1.387403130531311
# Beginning batch 560 of 587
# 	 Train Loss: 1.014572024345398
# Beginning batch 570 of 587
# 	 Train Loss: 1.2552214860916138
# Beginning batch 580 of 587
# 	 Train Loss: 2.2176384925842285
# Testing batch 0
# 	 Test Loss: 1.2745566368103027
# 	 Test Loss: 1.1479707956314087
# 	 Test Loss: 1.2909719944000244
# 	 Test Loss: 0.7082580924034119
# 	 Test Loss: 1.1660122871398926
# 	 Test Loss: 1.4178297519683838
# 	 Test Loss: 1.2253313064575195
# 	 Test Loss: 1.7553746700286865
# Beginning epoch 83
# Beginning batch 0 of 587
# 	 Train Loss: 1.4565951824188232
# Beginning batch 10 of 587
# 	 Train Loss: 1.1440393924713135
# Beginning batch 20 of 587
# 	 Train Loss: 1.4606770277023315
# Beginning batch 30 of 587
# 	 Train Loss: 1.1107923984527588
# Beginning batch 40 of 587
# 	 Train Loss: 0.803918719291687
# Beginning batch 50 of 587
# 	 Train Loss: 0.9811304211616516
# Beginning batch 60 of 587
# 	 Train Loss: 0.9521965980529785
# Beginning batch 70 of 587
# 	 Train Loss: 1.416283369064331
# Beginning batch 80 of 587
# 	 Train Loss: 1.3249552249908447
# Beginning batch 90 of 587
# 	 Train Loss: 0.9041770696640015
# Beginning batch 100 of 587
# 	 Train Loss: 0.9865323305130005
# Beginning batch 110 of 587
# 	 Train Loss: 1.3989989757537842
# Beginning batch 120 of 587
# 	 Train Loss: 1.7775551080703735
# Beginning batch 130 of 587
# 	 Train Loss: 1.043299913406372
# Beginning batch 140 of 587
# 	 Train Loss: 1.2154101133346558
# Beginning batch 150 of 587
# 	 Train Loss: 1.150977611541748
# Beginning batch 160 of 587
# 	 Train Loss: 1.3740155696868896
# Beginning batch 170 of 587
# 	 Train Loss: 1.0019842386245728
# Beginning batch 180 of 587
# 	 Train Loss: 1.2344410419464111
# Beginning batch 190 of 587
# 	 Train Loss: 1.139714002609253
# Beginning batch 200 of 587
# 	 Train Loss: 1.6269077062606812
# Beginning batch 210 of 587
# 	 Train Loss: 1.3432481288909912
# Beginning batch 220 of 587
# 	 Train Loss: 1.190706491470337
# Beginning batch 230 of 587
# 	 Train Loss: 1.2858785390853882
# Beginning batch 240 of 587
# 	 Train Loss: 1.3189259767532349
# Beginning batch 250 of 587
# 	 Train Loss: 0.8525663614273071
# Beginning batch 260 of 587
# 	 Train Loss: 0.8114088773727417
# Beginning batch 270 of 587
# 	 Train Loss: 1.4097554683685303
# Beginning batch 280 of 587
# 	 Train Loss: 1.0836256742477417
# Beginning batch 290 of 587
# 	 Train Loss: 0.8773212432861328
# Beginning batch 300 of 587
# 	 Train Loss: 1.1920605897903442
# Beginning batch 310 of 587
# 	 Train Loss: 1.0737470388412476
# Beginning batch 320 of 587
# 	 Train Loss: 1.9815667867660522
# Beginning batch 330 of 587
# 	 Train Loss: 0.9293028712272644
# Beginning batch 340 of 587
# 	 Train Loss: 1.3993611335754395
# Beginning batch 350 of 587
# 	 Train Loss: 1.2091621160507202
# Beginning batch 360 of 587
# 	 Train Loss: 1.3645274639129639
# Beginning batch 370 of 587
# 	 Train Loss: 1.4235092401504517
# Beginning batch 380 of 587
# 	 Train Loss: 1.3822968006134033
# Beginning batch 390 of 587
# 	 Train Loss: 1.2249411344528198
# Beginning batch 400 of 587
# 	 Train Loss: 1.0471752882003784
# Beginning batch 410 of 587
# 	 Train Loss: 1.0473864078521729
# Beginning batch 420 of 587
# 	 Train Loss: 1.053567886352539
# Beginning batch 430 of 587
# 	 Train Loss: 1.0580518245697021
# Beginning batch 440 of 587
# 	 Train Loss: 1.2217814922332764
# Beginning batch 450 of 587
# 	 Train Loss: 1.2055816650390625
# Beginning batch 460 of 587
# 	 Train Loss: 1.4220631122589111
# Beginning batch 470 of 587
# 	 Train Loss: 1.404381275177002
# Beginning batch 480 of 587
# 	 Train Loss: 1.110063076019287
# Beginning batch 490 of 587
# 	 Train Loss: 1.0833219289779663
# Beginning batch 500 of 587
# 	 Train Loss: 1.1868034601211548
# Beginning batch 510 of 587
# 	 Train Loss: 1.1286548376083374
# Beginning batch 520 of 587
# 	 Train Loss: 1.2375013828277588
# Beginning batch 530 of 587
# 	 Train Loss: 1.2057373523712158
# Beginning batch 540 of 587
# 	 Train Loss: 1.2534443140029907
# Beginning batch 550 of 587
# 	 Train Loss: 1.1646066904067993
# Beginning batch 560 of 587
# 	 Train Loss: 1.0293537378311157
# Beginning batch 570 of 587
# 	 Train Loss: 1.0986543893814087
# Beginning batch 580 of 587
# 	 Train Loss: 1.1939893960952759
# Testing batch 0
# 	 Test Loss: 1.2737027406692505
# 	 Test Loss: 1.1691057682037354
# 	 Test Loss: 1.1315250396728516
# 	 Test Loss: 0.8192678689956665
# 	 Test Loss: 0.9596497416496277
# 	 Test Loss: 1.5476884841918945
# 	 Test Loss: 1.2374022006988525
# 	 Test Loss: 1.678887963294983
# Beginning epoch 84
# Beginning batch 0 of 587
# 	 Train Loss: 1.1723439693450928
# Beginning batch 10 of 587
# 	 Train Loss: 1.1339614391326904
# Beginning batch 20 of 587
# 	 Train Loss: 1.1759803295135498
# Beginning batch 30 of 587
# 	 Train Loss: 1.2018015384674072
# Beginning batch 40 of 587
# 	 Train Loss: 1.2418467998504639
# Beginning batch 50 of 587
# 	 Train Loss: 1.3164862394332886
# Beginning batch 60 of 587
# 	 Train Loss: 0.8884913325309753
# Beginning batch 70 of 587
# 	 Train Loss: 1.541356086730957
# Beginning batch 80 of 587
# 	 Train Loss: 1.4987508058547974
# Beginning batch 90 of 587
# 	 Train Loss: 1.435657262802124
# Beginning batch 100 of 587
# 	 Train Loss: 1.6813112497329712
# Beginning batch 110 of 587
# 	 Train Loss: 1.4563376903533936
# Beginning batch 120 of 587
# 	 Train Loss: 1.480090618133545
# Beginning batch 130 of 587
# 	 Train Loss: 1.007378339767456
# Beginning batch 140 of 587
# 	 Train Loss: 0.8713734745979309
# Beginning batch 150 of 587
# 	 Train Loss: 0.8594130277633667
# Beginning batch 160 of 587
# 	 Train Loss: 1.098949909210205
# Beginning batch 170 of 587
# 	 Train Loss: 0.9814146757125854
# Beginning batch 180 of 587
# 	 Train Loss: 1.3508859872817993
# Beginning batch 190 of 587
# 	 Train Loss: 1.108006238937378
# Beginning batch 200 of 587
# 	 Train Loss: 1.1328272819519043
# Beginning batch 210 of 587
# 	 Train Loss: 1.2246843576431274
# Beginning batch 220 of 587
# 	 Train Loss: 1.3372920751571655
# Beginning batch 230 of 587
# 	 Train Loss: 1.065423607826233
# Beginning batch 240 of 587
# 	 Train Loss: 1.621953010559082
# Beginning batch 250 of 587
# 	 Train Loss: 0.9713870286941528
# Beginning batch 260 of 587
# 	 Train Loss: 0.9169991612434387
# Beginning batch 270 of 587
# 	 Train Loss: 1.2914862632751465
# Beginning batch 280 of 587
# 	 Train Loss: 1.1864473819732666
# Beginning batch 290 of 587
# 	 Train Loss: 1.2601251602172852
# Beginning batch 300 of 587
# 	 Train Loss: 1.7732646465301514
# Beginning batch 310 of 587
# 	 Train Loss: 1.4858660697937012
# Beginning batch 320 of 587
# 	 Train Loss: 1.0299142599105835
# Beginning batch 330 of 587
# 	 Train Loss: 1.3676785230636597
# Beginning batch 340 of 587
# 	 Train Loss: 0.971845805644989
# Beginning batch 350 of 587
# 	 Train Loss: 1.0983619689941406
# Beginning batch 360 of 587
# 	 Train Loss: 1.0844656229019165
# Beginning batch 370 of 587
# 	 Train Loss: 1.6328071355819702
# Beginning batch 380 of 587
# 	 Train Loss: 1.4626679420471191
# Beginning batch 390 of 587
# 	 Train Loss: 1.8821378946304321
# Beginning batch 400 of 587
# 	 Train Loss: 1.332716941833496
# Beginning batch 410 of 587
# 	 Train Loss: 1.2911255359649658
# Beginning batch 420 of 587
# 	 Train Loss: 0.9576629400253296
# Beginning batch 430 of 587
# 	 Train Loss: 1.3058290481567383
# Beginning batch 440 of 587
# 	 Train Loss: 1.2091147899627686
# Beginning batch 450 of 587
# 	 Train Loss: 1.490837812423706
# Beginning batch 460 of 587
# 	 Train Loss: 1.4597139358520508
# Beginning batch 470 of 587
# 	 Train Loss: 1.683896780014038
# Beginning batch 480 of 587
# 	 Train Loss: 1.1993627548217773
# Beginning batch 490 of 587
# 	 Train Loss: 1.3701727390289307
# Beginning batch 500 of 587
# 	 Train Loss: 1.380685806274414
# Beginning batch 510 of 587
# 	 Train Loss: 0.8629639744758606
# Beginning batch 520 of 587
# 	 Train Loss: 1.051637887954712
# Beginning batch 530 of 587
# 	 Train Loss: 0.9903445243835449
# Beginning batch 540 of 587
# 	 Train Loss: 1.3619580268859863
# Beginning batch 550 of 587
# 	 Train Loss: 1.3409093618392944
# Beginning batch 560 of 587
# 	 Train Loss: 1.0859509706497192
# Beginning batch 570 of 587
# 	 Train Loss: 1.1015989780426025
# Beginning batch 580 of 587
# 	 Train Loss: 1.0666059255599976
# Testing batch 0
# 	 Test Loss: 1.385046362876892
# 	 Test Loss: 1.4032442569732666
# 	 Test Loss: 1.2490161657333374
# 	 Test Loss: 0.7759054899215698
# 	 Test Loss: 0.9965202212333679
# 	 Test Loss: 1.3634307384490967
# 	 Test Loss: 1.403639554977417
# 	 Test Loss: 1.4778306484222412
# Beginning epoch 85
# Beginning batch 0 of 587
# 	 Train Loss: 1.1501555442810059
# Beginning batch 10 of 587
# 	 Train Loss: 1.3344844579696655
# Beginning batch 20 of 587
# 	 Train Loss: 0.9379462003707886
# Beginning batch 30 of 587
# 	 Train Loss: 1.5379059314727783
# Beginning batch 40 of 587
# 	 Train Loss: 1.1980355978012085
# Beginning batch 50 of 587
# 	 Train Loss: 1.4019142389297485
# Beginning batch 60 of 587
# 	 Train Loss: 0.8187468647956848
# Beginning batch 70 of 587
# 	 Train Loss: 1.1332093477249146
# Beginning batch 80 of 587
# 	 Train Loss: 1.111707329750061
# Beginning batch 90 of 587
# 	 Train Loss: 1.1941479444503784
# Beginning batch 100 of 587
# 	 Train Loss: 1.5087645053863525
# Beginning batch 110 of 587
# 	 Train Loss: 1.4827802181243896
# Beginning batch 120 of 587
# 	 Train Loss: 1.5778651237487793
# Beginning batch 130 of 587
# 	 Train Loss: 1.1713265180587769
# Beginning batch 140 of 587
# 	 Train Loss: 1.243193507194519
# Beginning batch 150 of 587
# 	 Train Loss: 0.7272480726242065
# Beginning batch 160 of 587
# 	 Train Loss: 0.9347103834152222
# Beginning batch 170 of 587
# 	 Train Loss: 1.1410083770751953
# Beginning batch 180 of 587
# 	 Train Loss: 0.8828119039535522
# Beginning batch 190 of 587
# 	 Train Loss: 1.0664291381835938

# %%
monitor_pth = "/home/yc506/ssrs/experiments/results/eurosat_resize_swav"

train_progress = pd.read_csv(os.path.join(monitor_pth,"performance.csv"))
fig,ax = plt.subplots()
ax.plot(train_progress.epoch[train_progress["stage"]=="train"],train_progress.loss[train_progress["stage"]=="train"],label="train")
ax.plot(train_progress.epoch[train_progress["stage"]=="val"],train_progress.loss[train_progress["stage"]=="val"],label="validation")
ax.set_xlabel("epoch")
ax.set_ylabel("Cross entropy loss")
ax.legend()
plt.show()

# %%
bestOrFinal = "best"
weights_folder = "/home/yc506/ssrs/experiments/results/eurosat_resize_swav"

encoderWeights_path = os.path.join(weights_folder,f"enc_{bestOrFinal}.pt")
decoderWeights_path = os.path.join(weights_folder,f"dec_{bestOrFinal}.pt")

# %%
# load the weigths we saved
encoder_trained = encoders._load_swav_pretrained("/scratch/mh613/model_paths/ckp-200-eval.pth")
decoder_trained = RegLog(10)
decoder_trained.load_state_dict(torch.load(decoderWeights_path))
encoder_trained = encoder_trained.eval()
decoder_trained = decoder_trained.eval()

encoder_trained = encoder_trained.to(DEVICE)
decoder_trained = decoder_trained.to(DEVICE)

# %%
def get_prediction_accuracy(dataloader, encoder, decoder):
    correct = 0
    total = 0
    for i, (img, label) in enumerate(dataloader):
        # Load through the model.
        img = img.to(DEVICE)
        label = label.to(DEVICE)
        with torch.no_grad():
            topk = (1, )
            maxk = max(topk)
            output = encoder(img)
            output = decoder(output[0])
            maxk = max(topk)
            batch_size = label.size(0)
            _, pred = output.topk(maxk, 1, True, True)
            pred = pred.t()
            correct = pred.eq(label.view(1, -1).expand_as(pred))
            res = []
            for k in topk:
                correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
                res.append(correct_k.mul_(100.0 / batch_size))
            return res

# %%
def get_prediction_accuracy(dataloader, encoder, decoder):
    #preds = []
    #targets = []
    correct = 0
    total = 0
    for i, (img, label) in enumerate(dataloader):
        # Load through the model.
        img = img.to(DEVICE)
        label = label.to(DEVICE)
        with torch.no_grad():
            output = encoder(img)
            output = decoder(output[0])
            pred_prob = torch.sigmoid(output) #activation function sigmoid function
            _, predicted = torch.max(pred_prob, 1) # the maximum probability class will be picked as our prediction 
            total += label.size(0) # the total number of prediction 
            correct += (predicted == label).sum().item() 
    return correct/total

# %%
test_dataset = load_eurosat("/scratch/yc506/NewEuroSat_rgb/" , evaluate=True)
test_loader = DataLoader(test_dataset, batch_size=20, shuffle=False)
get_prediction_accuracy(test_loader,encoder_trained,decoder_trained)
# Out:
# 0.5950920245398773

# %%
def get_prediction(dataloader, encoder, decoder):
    preds = []
    targets = []
    correct = 0
    total = 0
    for i, (img, label) in enumerate(dataloader):
        # Load through the model.
        img = img.to(DEVICE)
        label = label.to(DEVICE)
        with torch.no_grad():
            output = encoder(img)
            output = decoder(output[0])
            pred_prob = torch.sigmoid(output) #activation function sigmoid function
            preds.append(pred_prob.cpu())
            targets.append(label.cpu())
    return preds, targets
